# %%
import pandas as pd
import numpy as np
df=pd.read_csv("transactions.csv")
df[(df["t_date"]=="11-15-2015")]
# Out:
#            t_date  cust_id   t_amt                services  \
# 200    11-15-2015  4008344   41.92            Water Sports
# 1801   11-15-2015  4001191  158.90      Outdoor Recreation
# 2083   11-15-2015  4000041  108.56                 Jumping
# 2291   11-15-2015  4006266   96.44      Exercise & Fitness
# 2714   11-15-2015  4008446   22.66  Outdoor Play Equipment
# ...           ...      ...     ...                     ...
# 46763  11-15-2015  4001972  156.92            Water Sports
# 48612  11-15-2015  4004926   32.07            Water Sports
# 48924  11-15-2015  4006762  145.21                   Games
# 49301  11-15-2015  4006429  182.67            Indoor Games
# 49804  11-15-2015  4004346   13.74      Outdoor Recreation
#
#                            products_used              city       state  \
# 200            Scuba Diving & Snorkeling  Colorado Springs    Colorado
# 1801                                Golf  Colorado Springs    Colorado
# 2083              Trampoline Accessories     Jacksonville      Florida
# 2291   Weightlifting Machine Accessories        Huntsville     Alabama
# 2714                   Lawn Water Slides           Oakland  California
# ...                                  ...               ...         ...
# 46763                       Bodyboarding             Boise       Idaho
# 48612                        Kitesurfing              Reno      Nevada
# 48924                            Mahjong       Kansas City    Missouri
# 49301                           Foosball          Columbus     Georgia
# 49804     Camping & Backpacking & Hiking       Chattanooga   Tennessee
#
#       t_details
# 200      credit
# 1801     credit
# 2083     credit
# 2291     credit
# 2714     credit
# ...         ...
# 46763    credit
# 48612    credit
# 48924    credit
# 49301    credit
# 49804    credit
#
# [133 rows x 8 columns]

# %% [markdown]
# ### What is the total sales amount across all transactions?

# %%
df["t_details"].value_counts(dropna=False)
# Out:
# t_details
# credit    43151
# cash       6849
# Name: count, dtype: int64

# %%
df["t_amt"].value_counts(dropna=False)
# Out:
# t_amt
# 109.17    11
# 154.13    11
# 46.82     10
# 152.18    10
# 198.91    10
#           ..
# 106.38     1
# 121.39     1
# 180.28     1
# 193.63     1
# 98.81      1
# Name: count, Length: 17920, dtype: int64

# %%
df["t_amt"].sum()
# Out:
# np.float64(5110820.54)

# %% [markdown]
# ### Which month had the highest total transaction amount?

# %%
x=df["t_date"][df["t_amt"].max()]
month=int(x[0:2])
month
# Out:
# 11

# %% [markdown]
# ### What is the average transaction amount per customer?

# %%
df.groupby("cust_id")["t_amt"].mean()
# Out:
# cust_id
# 4000000    127.444000
# 4000001    108.945556
# 4000002     56.165000
# 4000003    123.670000
# 4000004    168.135000
#               ...
# 4009995     65.018571
# 4009996    104.515000
# 4009997    121.547500
# 4009998    110.950000
# 4009999     85.252500
# Name: t_amt, Length: 9926, dtype: float64

# %% [markdown]
# ### What is the trend of total sales over months?

# %%
df["month"]=df["t_date"].str[0:2]
df.groupby("month")["t_amt"].sum()
# Out:
# month
# 01    438165.76
# 02    395262.37
# 03    444664.24
# 04    420695.24
# 05    432627.58
# 06    421074.55
# 07    439560.80
# 08    434255.01
# 09    429321.63
# 10    424856.28
# 11    408846.35
# 12    421490.73
# Name: t_amt, dtype: float64

# %% [markdown]
# ### What is the highest single transaction amount recorded?

# %%
df["t_amt"].max()
# Out:
# np.float64(200.0)

# %% [markdown]
# ### Which service category contributes the most to total revenue?

# %%
df.groupby("services")["t_amt"].sum().tail(1)
# Out:
# services
# Winter Sports    321973.56
# Name: t_amt, dtype: float64

# %% [markdown]
# ### Which product generated the highest revenue?

# %%
df.groupby("products_used")["t_amt"].sum().tail(1)
# Out:
# products_used
# Yoga & Pilates    47804.94
# Name: t_amt, dtype: float64

# %% [markdown]
# ### How does the average transaction amount vary between services?

# %%
df.groupby("services")["t_amt"].mean()
# Out:
# services
# Air Sports                103.455104
# Combat Sports             101.061761
# Dancing                   102.907512
# Exercise & Fitness        103.660247
# Games                     102.272968
# Gymnastics                102.385901
# Indoor Games              103.074684
# Jumping                   102.155171
# Outdoor Play Equipment    101.281196
# Outdoor Recreation        100.999480
# Puzzles                   100.595997
# Racquet Sports            103.647461
# Team Sports               102.738998
# Water Sports              101.899975
# Winter Sports             101.217718
# Name: t_amt, dtype: float64

# %% [markdown]
# ### How many unique customers made purchases?

# %%
df["cust_id"].nunique()
# Out:
# 9926

# %% [markdown]
# ### Which customers have spent the most overall?

# %%
df.groupby("cust_id")["t_amt"].sum().tail(1)
# Out:
# cust_id
# 4009999    682.02
# Name: t_amt, dtype: float64

# %% [markdown]
# ### What is the average number of transactions per customer?

# %%
df.groupby("cust_id")["t_amt"].count()
#df[df["cust_id"]==4000002]
# Out:
# cust_id
# 4000000    5
# 4000001    9
# 4000002    2
# 4000003    3
# 4000004    4
#           ..
# 4009995    7
# 4009996    8
# 4009997    4
# 4009998    6
# 4009999    8
# Name: t_amt, Length: 9926, dtype: int64

# %% [markdown]
# ### Are there customers who made multiple purchases in different categories?

# %%
x=df.groupby("cust_id").filter(lambda x:x["services"].nunique()==2)
x
# Out:
#            t_date  cust_id   t_amt            services    products_used  \
# 30     03-14-2015  4009693   47.05        Water Sports         Swimming
# 56     06-21-2015  4008744  176.63  Outdoor Recreation       Geocaching
# 59     11-07-2015  4002854   21.43       Winter Sports     Snowboarding
# 66     02-05-2015  4006293   89.14  Outdoor Recreation       Tetherball
# 71     01-26-2015  4009360  152.21         Team Sports          Cricket
# ...           ...      ...     ...                 ...              ...
# 49848  07-22-2015  4006571  166.54         Team Sports          Curling
# 49880  06-29-2015  4001913   75.02        Indoor Games        Billiards
# 49888  04-19-2015  4008433  124.88          Gymnastics  Vaulting Horses
# 49912  11-05-2015  4002703  159.28          Air Sports       Parachutes
# 49990  08-10-2015  4002940  144.91  Exercise & Fitness   Medicine Balls
#
#                city           state t_details month
# 30          Lincoln        Nebraska    credit    03
# 56           Boston   Massachusetts    credit    06
# 59     Philadelphia    Pennsylvania      cash    11
# 66          Gresham          Oregon    credit    02
# 71         Portland          Oregon    credit    01
# ...             ...             ...       ...   ...
# 49848     Lexington        Kentucky    credit    07
# 49880     Charlotte  North Carolina    credit    06
# 49888   Jersey City      New Jersey    credit    04
# 49912       Orlando         Florida    credit    11
# 49990   Minneapolis       Minnesota    credit    08
#
# [3187 rows x 9 columns]

# %% [markdown]
# ### what percentage of customers are repeat buyers

# %% [markdown]
# ### Which product category has the highest total sales?

# %%
df.groupby("products_used")["t_amt"].sum().tail(1)
# Out:
# products_used
# Yoga & Pilates    47804.94
# Name: t_amt, dtype: float64

# %% [markdown]
# ### Which services are most popular by transaction count?

# %%
df.groupby("services")["t_amt"].sum().tail(1)
# Out:
# services
# Winter Sports    321973.56
# Name: t_amt, dtype: float64

# %% [markdown]
# ### For each service, which product type is purchased most frequently?

# %%
df.groupby("services")["products_used"].count().sort_values(ascending=False).head(1)
# Out:
# services
# Outdoor Recreation    8383
# Name: products_used, dtype: int64

# %% [markdown]
# ### What is the average transaction amount per product type?

# %%
df.groupby("products_used")["t_amt"].mean()
# Out:
# products_used
# Abdominal Equipment    105.362798
# Air Hockey             103.775478
# Air Suits              101.421832
# Archery                 97.345564
# Badminton              108.441138
#                           ...
# Wetsuits               102.042775
# Whitewater Rafting     102.877744
# Windsurfing            104.161453
# Wrestling               97.895364
# Yoga & Pilates         107.668784
# Name: t_amt, Length: 125, dtype: float64

# %% [markdown]
# ### Are there specific services where customers spend significantly more?

# %%
x=df.groupby("services")["t_amt"].sum().sum()
x=x/50000
x
y=df.groupby("services").filter(lambda i:i["t_amt"].sum()>x)
y.groupby("services")["t_amt"].sum().sort_values(ascending=False).head(1)
# Out:
# services
# Outdoor Recreation    846678.64
# Name: t_amt, dtype: float64

# %% [markdown]
# ### Which state has the highest total sales?

# %%
df.groupby("state")["t_amt"].sum().sort_values(ascending=False).head(1)
# Out:
# state
# California    702346.23
# Name: t_amt, dtype: float64

# %% [markdown]
# ### Which city records the highest number of transactions?

# %%
df.groupby("city")["t_amt"].sum().sort_values(ascending=False).head(1)
# Out:
# city
# Pasadena    95533.98
# Name: t_amt, dtype: float64

# %% [markdown]
# ### What is the average spending per transaction in each state?

# %%
df.groupby("state")["t_amt"].mean()
# Out:
# state
# Alabama                 102.487049
# Arizona                 102.172241
# California              102.652182
# Colorado                101.537415
# Connecticut              99.982108
# District of Columbia    103.800334
# Florida                 103.136567
# Georgia                 102.330675
# Hawaii                  101.536667
# Idaho                    98.969538
# Illinois                100.166315
# Indiana                 100.712664
# Iowa                    103.100727
# Kansas                  101.436926
# Kentucky                104.130392
# Louisiana               103.466335
# Maryland                100.506913
# Massachusetts           104.541571
# Michigan                101.547777
# Minnesota               103.465157
# Mississippi             101.214926
# Missouri                100.969040
# Nebraska                101.955690
# Nevada                  105.434718
# New Jersey              103.438005
# New York                100.259452
# North Carolina          103.033172
# Ohio                    101.350817
# Oklahoma                104.995771
# Oregon                  102.438143
# Pennsylvania            102.776034
# South Carolina          103.540065
# Tennessee                99.265804
# Texas                   101.379891
# Utah                    104.507560
# Virginia                104.976206
# Washington              101.401603
# Wisconsin               101.953159
# Name: t_amt, dtype: float64

# %% [markdown]
# ### Are certain services more popular in specific states?

# %%
df.value_counts(["state", "services"])
# Out:
# state           services
# California      Outdoor Recreation    1188
#                 Exercise & Fitness     988
# Texas           Outdoor Recreation     830
#                 Exercise & Fitness     818
# California      Team Sports            816
#                                       ...
# Maryland        Dancing                  3
# North Carolina  Dancing                  2
# Mississippi     Puzzles                  2
# Hawaii          Dancing                  2
#                 Air Sports               2
# Name: count, Length: 570, dtype: int64

# %% [markdown]
# ### Which states buy the most Outdoor Recreation products?

# %%
x=df[df["services"]=="Outdoor Recreation"]
x["state"].value_counts()
# Out:
# state
# California              1188
# Texas                    830
# Florida                  483
# Oregon                   335
# Tennessee                313
# Ohio                     307
# Colorado                 279
# Washington               276
# Massachusetts            253
# Arizona                  247
# Missouri                 226
# New Jersey               225
# Illinois                 224
# Alabama                  191
# Virginia                 186
# Wisconsin                180
# Minnesota                169
# South Carolina           162
# Kentucky                 156
# Kansas                   154
# Pennsylvania             154
# Georgia                  153
# North Carolina           153
# Michigan                 152
# Nebraska                 149
# Connecticut              140
# New York                 140
# Utah                     136
# Nevada                   135
# Indiana                   91
# Idaho                     81
# Maryland                  80
# Mississippi               78
# Louisiana                 77
# Iowa                      74
# Hawaii                    72
# Oklahoma                  70
# District of Columbia      64
# Name: count, dtype: int64

# %% [markdown]
# ### Compare average spending between California and Texas customers.

# %%
x=df[df["state"]=="California"]
y=df[df["state"]=="Texas"]
print("California:",x["t_amt"].sum())
print("Texas:",y["t_amt"].sum())
# Out:
# California: 702346.23
# Texas: 541267.24

# %% [markdown]
# ### Which quarter of the year saw the highest sales?

# %%
x=df["t_date"][df["t_amt"].max()]
x=int(x[0:2])
if 1<=x<=4:
    print("First Quarter")
elif 4<x<=8:
    print("Second Quarter")
else:
    print("Third Quarter")
# Out:
# Third Quarter

# %% [markdown]
# ### How does total sales vary month by month?

# %%
df.groupby("month")["t_amt"].sum()
# Out:
# month
# 01    438165.76
# 02    395262.37
# 03    444664.24
# 04    420695.24
# 05    432627.58
# 06    421074.55
# 07    439560.80
# 08    434255.01
# 09    429321.63
# 10    424856.28
# 11    408846.35
# 12    421490.73
# Name: t_amt, dtype: float64

# %% [markdown]
# ### What is the total number of transactions per month?

# %%
df.groupby("month")["t_amt"].sum()
# Out:
# month
# 01    438165.76
# 02    395262.37
# 03    444664.24
# 04    420695.24
# 05    432627.58
# 06    421074.55
# 07    439560.80
# 08    434255.01
# 09    429321.63
# 10    424856.28
# 11    408846.35
# 12    421490.73
# Name: t_amt, dtype: float64

# %% [markdown]
# ### Is there a particular season when sports equipment sales spike?

# %%
df["services"].value_counts()
# Out:
# services
# Outdoor Recreation        8383
# Exercise & Fitness        7394
# Team Sports               6010
# Water Sports              5219
# Games                     3666
# Gymnastics                3196
# Winter Sports             3181
# Outdoor Play Equipment    2910
# Indoor Games              2799
# Jumping                   2015
# Combat Sports             1630
# Racquet Sports            1611
# Air Sports                 960
# Puzzles                    612
# Dancing                    414
# Name: count, dtype: int64

# %% [markdown]
# ### How many transactions were done using credit?

# %%
df.groupby("t_details")["t_amt"].count().tail(1)
# Out:
# t_details
# credit    43151
# Name: t_amt, dtype: int64

# %% [markdown]
# ### What is the total revenue generated from credit transactions?

# %%
df.groupby("t_details")["t_amt"].sum().tail(1)
# Out:
# t_details
# credit    4923134.93
# Name: t_amt, dtype: float64

# %% [markdown]
# ### Is there a difference in average spending between credit and cash customers?

# %%
x=df.groupby("t_details")["t_amt"].sum().tail(1).max()
y=df.groupby("t_details")["t_amt"].sum().head(1).max()
print("Credit-Cash:",y-x)
# Out:
# Credit-Cash: -4735449.319999999

# %% [markdown]
# ### Which states or cities should the company focus on for marketing high-value products?

# %%
x=df.groupby(["products_used","state"])["t_amt"].sum().sort_values(ascending=False).head(9)
x
# Out:
# products_used           state
# Swing Sets              California    8570.77
# Yoga & Pilates          California    8090.65
# Weightlifting Machines  California    7642.54
# Basketball              California    7428.87
# Swimming                California    7369.48
# Golf                    California    7297.54
# Mahjong                 California    7219.48
# Board Games             California    7186.08
# Cheerleading            California    7091.34
# Name: t_amt, dtype: float64

# %% [markdown]
# ### Should more inventory be stocked for Exercise & Fitness products given their popularity?

# %% [markdown]
# ### Are there product categories with high sales but low average transaction amounts?

# %%
df.groupby("products_used")["t_amt"].agg(["sum", "mean"])
# Out:
#                           sum        mean
# products_used
# Abdominal Equipment  43304.11  105.362798
# Air Hockey           40161.11  103.775478
# Air Suits            19371.57  101.421832
# Archery              37088.66   97.345564
# Badminton            44786.19  108.441138
# ...                       ...         ...
# Wetsuits             38980.34  102.042775
# Whitewater Rafting   41048.22  102.877744
# Windsurfing          43018.68  104.161453
# Wrestling            40332.89   97.895364
# Yoga & Pilates       47804.94  107.668784
#
# [125 rows x 2 columns]

# %% [markdown]
# ### Are there underperforming service categories that need promotional offers?

# %%
x=df.groupby("services")["t_amt"].transform("mean")
df[df["t_amt"]<x]
# Out:
#            t_date  cust_id  t_amt                services  \
# 0      06-26-2015  4007024  40.33      Exercise & Fitness
# 2      06-01-2015  4009775   5.58      Exercise & Fitness
# 4      12-17-2015  4002613  98.81             Team Sports
# 6      10-28-2015  4002190  27.89                 Puzzles
# 7      07-14-2015  4002964  96.01  Outdoor Play Equipment
# ...           ...      ...    ...                     ...
# 49987  09-07-2015  4003274   7.65                   Games
# 49988  08-13-2015  4007405  65.54           Winter Sports
# 49993  06-02-2015  4007367  50.32             Team Sports
# 49995  09-18-2015  4005664  53.95                   Games
# 49997  05-03-2015  4003954  35.85          Racquet Sports
#
#                            products_used           city           state  \
# 0             Cardio Machine Accessories    Clarksville       Tennessee
# 2      Weightlifting Machine Accessories        Anaheim      California
# 4                           Field Hockey    Nashville         Tennessee
# 6                         Jigsaw Puzzles     Charleston  South Carolina
# 7                              Sandboxes       Columbus            Ohio
# ...                                  ...            ...             ...
# 49987                         Bingo Sets         Durham  North Carolina
# 49988               Cross-Country Skiing  Oklahoma City        Oklahoma
# 49993                       Field Hockey       Stamford     Connecticut
# 49995                         Dice Games         Irving           Texas
# 49997                             Squash    New Orleans       Louisiana
#
#       t_details month
# 0        credit    06
# 2        credit    06
# 4        credit    12
# 6        credit    10
# 7        credit    07
# ...         ...   ...
# 49987      cash    09
# 49988    credit    08
# 49993    credit    06
# 49995    credit    09
# 49997      cash    05
#
# [25102 rows x 9 columns]
